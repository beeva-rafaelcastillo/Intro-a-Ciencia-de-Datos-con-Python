# %% [markdown]
# ### Requisitos:
#
# Para el curso será necesario tener instalado:
#  * Python 2.7
#  * Numpy
#  * Scikit Learn
#  * Pandas
#  * Ipython notebook
#
# Como alternativa, podeis instalar [Anaconda 2.7](https://www.continuum.io/downloads) y si estais familiarizados con Docker, podéis descargar alguna [imagen](https://github.com/ContinuumIO/docker-images/tree/master/anaconda).

# %% [markdown]
# ### Comprobar la instalación:
#
# El siguiente [ejercicio](http://scikit-learn.org/stable/auto_examples/decomposition/plot_ica_vs_pca.html#example-decomposition-plot-ica-vs-pca-py) esta diseñado para comprobar el estado de la instalación, el resultado del ejercicio tiene que ser la siguiente imagen:

# %%
from IPython.display import Image
Image(filename='FastICA.png')

# %% [markdown]
# ### Código de Prueba
# Ejecutar el siguiente código para comprobar el estado de la instalación: (tardará unos segundos en ejecutarse)

# %%
# %matplotlib inline

# Authors: Alexandre Gramfort, Gael Varoquaux
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA, FastICA

###############################################################################
# Generate sample data
rng = np.random.RandomState(42)
S = rng.standard_t(1.5, size=(20000, 2))
S[:, 0] *= 2.

# Mix data
A = np.array([[1, 1], [0, 2]])  # Mixing matrix

X = np.dot(S, A.T)  # Generate observations

pca = PCA()
S_pca_ = pca.fit(X).transform(X)

ica = FastICA(random_state=rng)
S_ica_ = ica.fit(X).transform(X)  # Estimate the sources

S_ica_ /= S_ica_.std(axis=0)


###############################################################################
# Plot results

def plot_samples(S, axis_list=None):
    plt.scatter(S[:, 0], S[:, 1], s=2, marker='o', zorder=10,
                color='steelblue', alpha=0.5)
    if axis_list is not None:
        colors = ['orange', 'red']
        for color, axis in zip(colors, axis_list):
            axis /= axis.std()
            x_axis, y_axis = axis
            # Trick to get legend to work
            plt.plot(0.1 * x_axis, 0.1 * y_axis, linewidth=2, color=color)
            plt.quiver(0, 0, x_axis, y_axis, zorder=11, width=0.01, scale=6,
                       color=color)

    plt.hlines(0, -3, 3)
    plt.vlines(0, -3, 3)
    plt.xlim(-3, 3)
    plt.ylim(-3, 3)
    plt.xlabel('x')
    plt.ylabel('y')

plt.figure()
plt.subplot(2, 2, 1)
plot_samples(S / S.std())
plt.title('True Independent Sources')

axis_list = [pca.components_.T, ica.mixing_]
plt.subplot(2, 2, 2)
plot_samples(X / np.std(X), axis_list=axis_list)
legend = plt.legend(['PCA', 'ICA'], loc='upper right')
legend.set_zorder(100)

plt.title('Observations')

plt.subplot(2, 2, 3)
plot_samples(S_pca_ / np.std(S_pca_, axis=0))
plt.title('PCA recovered signals')

plt.subplot(2, 2, 4)
plot_samples(S_ica_ / np.std(S_ica_))
plt.title('ICA recovered signals')

plt.subplots_adjust(0.09, 0.04, 0.94, 0.94, 0.26, 0.36)
plt.show()

# %% [markdown]
# **Si el resultado de la ejecución es la imagen que se esperaba,significa que ya estás listo para el curso!!**. Si por el contrario has tenido algún problema ejecutando el código, revisa tu instalación y ejecutalo de nuevo.
